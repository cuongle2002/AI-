# %% [markdown]
# <a href="https://colab.research.google.com/github/cuongle2002/AI-/blob/main/AI_WEEK_12(mtcnn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 47.9 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt 
from mtcnn import MTCNN
filename = "/content/ảnh tập thể.jpg"
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces: 
  print(face)     #2 gt dau la goc toa do , 3 là cr, 4 là cd
# Out:
# ...
# 7/7 [==============================] - 0s 4ms/step
# {'box': [1368, 906, 68, 88], 'confidence': 1.0, 'keypoints': {'left_eye': (1390, 942), 'right_eye': (1422, 941), 'nose': (1408, 961), 'mouth_left': (1391, 970), 'mouth_right': (1422, 970)}}
# {'box': [665, 905, 82, 102], 'confidence': 0.9999996423721313, 'keypoints': {'left_eye': (691, 944), 'right_eye': (729, 949), 'nose': (708, 966), 'mouth_left': (687, 980), 'mouth_right': (722, 983)}}
# {'box': [1967, 928, 84, 99], 'confidence': 0.9999938011169434, 'keypoints': {'left_eye': (1987, 964), 'right_eye': (2029, 964), 'nose': (2008, 984), 'mouth_left': (1988, 1002), 'mouth_right': (2025, 1003)}}
# {'box': [1686, 815, 40, 48], 'confidence': 0.9999912977218628, 'keypoints': {'left_eye': (1701, 833), 'right_eye': (1719, 833), 'nose': (1712, 842), 'mouth_left': (1702, 852), 'mouth_right': (1718, 852)}}
# ...

# %%
import matplotlib.pyplot as plt 
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/Anhtapthe /ảnh tập thể bóng đá.jpg'
detetor = MTCNN()
faces = detector.detect_faces(img)
img = plt.imread(filename)
plt.imshow(img)
ax = plt.gca()

for face in faces: 
  x,y,width,height = face['box']
  red = plt.Rectangle((x,y),width,height,
                      fill = False, color = 'red')
  ax.add_patch(red)
  for key,value in face['keypoints'].item():
    dot = plt.Circle(value)
  plt.savefig('/content/drive/MyDrive/MTCNN/test.jpg')

plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 26ms/step

# %%
import matplotlib.pyplot as plt 
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/Anhtapthe /ảnh khẩu trang.jpg'
detetor = MTCNN()
faces = detector.detect_faces(img)
img = plt.imread(filename)
plt.imshow(img)
ax = plt.gca()

for face in faces: 
  x,y,width,height = face['box']
  red = plt.Rectangle((x,y),width,height,
                      fill = False, color = 'red')
  ax.add_patch(red) 
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value,radius = 2, color = 'red')
    ax.add_patch(dot)
  #plt.savefig('/content/drive/MyDrive/MTCNN/test.jpg')
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 4ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt 
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/Anhtapthe /ảnh chó becgie.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357
plt.imshow(img)
# Out:
# WARNING:tensorflow:5 out of the last 28 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab6aae040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 929ms/step
# Predicted: [('n02106662', 'German_shepherd', 0.97510684), ('n02105162', 'malinois', 0.02207814), ('n02115641', 'dingo', 0.0017309485)]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt 
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/Anhtapthe /ảnh chó becgie.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 897ms/step
# Predicted: [('n02106662', 'German_shepherd', 0.97510684), ('n02105162', 'malinois', 0.02207814), ('n02115641', 'dingo', 0.0017309485)]

# %%
model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/Anhtapthe /ảnh con snake.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357
plt.imshow(img)
# Out:
# WARNING:tensorflow:6 out of the last 29 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab6aae9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 895ms/step
# Predicted: [('n01742172', 'boa_constrictor', 0.33335152), ('n01753488', 'horned_viper', 0.22753422), ('n01740131', 'night_snake', 0.21962242)]

# %%
model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/Anhtapthe /ảnh nấm.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357
plt.imshow(img)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted: [('n07734744', 'mushroom', 0.98799217), ('n13054560', 'bolete', 0.0059600174), ('n12998815', 'agaric', 0.0035389743)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=True)

img_path = '/content/drive/MyDrive/Anhtapthe /xe motor.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=1)[0])
plt.imshow(img)
# Out:
# ...
# 1/1 [==============================] - 0s 230ms/step
# Predicted: [('n03785016', 'moped', 0.458102)]

# %%
model = VGG16(weights='imagenet', include_top=True)

img_path = '/content/drive/MyDrive/Anhtapthe /kiến trúc.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=1)[0])
plt.imshow(img)
# Out:
# 1/1 [==============================] - 0s 217ms/step
# Predicted: [('n04311004', 'steel_arch_bridge', 0.56194067)]

# %%
pip install youtube_search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from youtube_search import YoutubeSearch 
import webbrowser
while True:
  mysong = input("Nhap ten bai hat: ")
  result = YoutubeSearch(mysong,max_results=10).to_dict()
  print(result)
  print(result[0]['url_suffix'])
  url = 'http://www.youtube.com' + result[0]['url_suffix']
  print(url)
  #webbrowser.open(url)
  print("Bài hát yêu thích của bạn đã được mở")
# Out:
# Nhap ten bai hat: hãy trao cho anh
# ...

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from youtube_search import YoutubeSearch 
import webbrowser
from openpyxl import Workbook
data = Workbook()
sheet = data.active 
mysong = input('Xin mời bạn chọn tên bài hát: ')
print(mysong)
result = YoutubeSearch(mysong,max_results = 10).to_dict()
print(result)
for i in range(10):
  print(result[i]['title'])
  print(result[i]['url_suffix'])
  url = 'http://www.youtube.com' + result[i]['url_suffix']
  print(url)
  sheet['A'+str(i+1)] = i+1
  sheet['B'+str(i+1)] = result[i]['title']
  sheet['C'+str(i+1)] = result[i]['url_suffix']
  sheet['D'+str(i+1)] = result[i]['views']
  sheet['E'+str(i+1)] = result[i]['duration']
  sheet['F'+str(i+1)] = result[i]['publish_time']
  sheet['G'+str(i+1)] = result[i]['channel']


data.save("UTE.xlsx")
# Out:
# Xin mời bạn chọn tên bài hát: chạy ngay đi
# chạy ngay đi
# ...
